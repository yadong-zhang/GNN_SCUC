# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read PF data
num_data = 100

num_branches = 1991

nt = 12

file_path = f'../outputs/PF/sample_{1}.csv'
all_PF = pd.read_csv(file_path, header=None, index_col=None)

for i in range(1, num_data):
    file_path = f'../outputs/PF/sample_{i+1}.csv'
    try:
        PF = pd.read_csv(file_path, header=None, index_col=None).to_numpy()
    except FileNotFoundError:
        print(f'File sample_{i+1}.csv is not found.')
        continue
    all_PF = np.concatenate([all_PF, PF], axis=1)
# Out:
# File sample_21.csv is not found.
# File sample_22.csv is not found.
# File sample_23.csv is not found.
# File sample_24.csv is not found.
# File sample_25.csv is not found.
# File sample_26.csv is not found.
# File sample_27.csv is not found.
# File sample_28.csv is not found.
# File sample_29.csv is not found.
# File sample_30.csv is not found.
# File sample_31.csv is not found.
# File sample_32.csv is not found.
# File sample_33.csv is not found.
# File sample_34.csv is not found.
# File sample_35.csv is not found.
# File sample_36.csv is not found.
# File sample_37.csv is not found.
# File sample_38.csv is not found.
# File sample_39.csv is not found.
# File sample_40.csv is not found.
# File sample_41.csv is not found.
# File sample_42.csv is not found.
# File sample_43.csv is not found.
# File sample_44.csv is not found.
# File sample_45.csv is not found.
# File sample_46.csv is not found.
# File sample_47.csv is not found.
# File sample_48.csv is not found.
# File sample_49.csv is not found.
# File sample_50.csv is not found.
# File sample_51.csv is not found.
# File sample_52.csv is not found.
# File sample_53.csv is not found.
# File sample_54.csv is not found.
# File sample_55.csv is not found.
# File sample_56.csv is not found.
# File sample_57.csv is not found.
# File sample_58.csv is not found.
# File sample_59.csv is not found.
# File sample_60.csv is not found.
# File sample_61.csv is not found.
# File sample_62.csv is not found.
# File sample_63.csv is not found.
# File sample_64.csv is not found.
# File sample_65.csv is not found.
# File sample_66.csv is not found.
# File sample_67.csv is not found.
# File sample_68.csv is not found.
# File sample_69.csv is not found.
# File sample_70.csv is not found.
# File sample_71.csv is not found.
# File sample_72.csv is not found.
# File sample_73.csv is not found.
# File sample_74.csv is not found.
# File sample_75.csv is not found.
# File sample_76.csv is not found.
# File sample_77.csv is not found.
# File sample_78.csv is not found.
# File sample_79.csv is not found.
# File sample_80.csv is not found.
# File sample_81.csv is not found.
# File sample_82.csv is not found.
# File sample_83.csv is not found.
# File sample_84.csv is not found.
# File sample_85.csv is not found.
# File sample_86.csv is not found.
# File sample_87.csv is not found.
# File sample_88.csv is not found.
# File sample_89.csv is not found.
# File sample_90.csv is not found.
# File sample_91.csv is not found.
# File sample_92.csv is not found.
# File sample_93.csv is not found.
# File sample_94.csv is not found.
# File sample_95.csv is not found.
# File sample_96.csv is not found.
# File sample_97.csv is not found.
# File sample_98.csv is not found.
# File sample_99.csv is not found.
# File sample_100.csv is not found.

# %%
# Get max of PF
PF_max = np.abs(all_PF).max(axis=1)

# %%
# Plot min, median and max of PF
fig = plt.figure(figsize=(15, 3))
ax = fig.add_subplot(111)
ax.plot(PF_max, label='PF_Max')
ax.set_yscale('log')
ax.set_ylim((100, 3000))
ax.set_xlabel('Branches')
ax.legend()

# fig.savefig('PF_max.jpg')

plt.tight_layout()
plt.show()
plt.close('all')

# %%
# Select three categories of PF_Max
bidx1 = PF_max <= 500
bidx2 = (PF_max > 500) & (PF_max <= 1000)
bidx3 = PF_max > 1000

# %%
bidx1.shape, bidx2.shape, bidx3.shape
# Out:
# ((1991,), (1991,), (1991,))

# %%
bidx1.sum(), bidx2.sum(), bidx3.sum()
# Out:
# (1717, 184, 90)

# %%
pd.DataFrame(bidx1.astype(float)).to_csv('./PF_max_category1.csv', header=None, index=None, columns=None)
pd.DataFrame(bidx2.astype(float)).to_csv('./PF_max_category2.csv', header=None, index=None, columns=None)
pd.DataFrame(bidx3.astype(float)).to_csv('./PF_max_category3.csv', header=None, index=None, columns=None)
