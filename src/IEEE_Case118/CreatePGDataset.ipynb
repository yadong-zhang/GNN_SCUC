# %%
import os
import shutil
import random
import numpy as np
import pandas as pd

import torch
from torch_geometric.data import Data

# %% [markdown]
# ## Read grid info

# %%
# Create buses
num_buses = 118
buses = np.arange(1, num_buses+1)

# Read gen buses
file_path = '../../data/IEEE_Case118/zones/gen_bus.csv'
gen_buses = pd.read_csv(file_path, header=None, index_col=None)

# Read thermal buses
file_path = '../../data/IEEE_Case118/zones/thermal_bus.csv'
thermal_buses = pd.read_csv(file_path, header=None, index_col=None)

# Read wind gen buses
file_path = '../../data/IEEE_Case118/zones/wind_bus.csv'
wind_buses = pd.read_csv(file_path, header=None, index_col=None)

# Read load buses
file_path = '../../data/IEEE_Case118/zones/load_bus.csv'
load_buses = pd.read_csv(file_path, header=None, index_col=None)

# %%
# Boolean index of thermal buses
thermal_bidx = np.isin(buses, thermal_buses)

# Boolean index of wind buses
wind_bidx = np.isin(buses, wind_buses)

# Boolean index of load buses
load_bidx = np.isin(buses, load_buses)

# %%
# Get thermal gen features (To be determined)
Pmax = pd.read_csv('../../data/IEEE_Case118/gen_params/Pmax.csv',
                   header=None,
                   index_col=None)
Pmin = pd.read_csv('../../data/IEEE_Case118/gen_params/Pmin.csv',
                   header=None,
                   index_col=None)
ramp_30 = pd.read_csv('../../data/IEEE_Case118/gen_params/ramp_30.csv',
                      header=None,
                      index_col=None)
startup_cost = pd.read_csv('../../data/IEEE_Case118/gen_params/startup_cost.csv',
                            header=None,
                            index_col=None)
shutdown_cost = pd.read_csv('../../data/IEEE_Case118/gen_params/shutdown_cost.csv',
                            header=None,
                            index_col=None)
gencost_params = pd.read_csv('../../data/IEEE_Case118/gen_params/gencost_params.csv',
                                header=None,
                                index_col=None)
reserve_qty = pd.read_csv('../../data/IEEE_Case118/gen_params/reserve_qty.csv',
                            header=None,
                            index_col=None)
reserve_cost = pd.read_csv('../../data/IEEE_Case118/gen_params/reserve_cost.csv',
                            header=None,
                            index_col=None)

# Get the Boolean idx of thermals in gens
bidx = np.isin(gen_buses, thermal_buses).reshape((-1))

temp = np.concatenate([pd.concat([Pmax]*12, axis=1), pd.concat([Pmin]*12, axis=1), pd.concat([ramp_30]*12, axis=1), pd.concat([startup_cost]*12, axis=1), 
                  pd.concat([shutdown_cost]*12, axis=1), pd.concat([gencost_params]*12, axis=1)], axis=1)

temp2 =np.concatenate([pd.concat([reserve_qty]*12, axis=1), pd.concat([reserve_cost]*12, axis=1)], axis=1)

# Create thermal gens features
thermal_gen_features = np.concatenate([temp[bidx], temp2], axis=1)

# %%
# Time steps
nt = 12

# Read wind and load inputs into MATPOWER
num_samples = 1000

# %% [markdown]
# ## PG ground truth

# %%
# Read MATPOWER UC solution
y_PG = []

# Add zeros to make the dimension as [num_buses, nt*2]
# all_PG = np.zeros((num_buses, nt*2))
all_PG = np.zeros((num_buses, nt))

max_num = 1199
for i in range(max_num):
    thermal_PG_path = f'../../data/IEEE_Case118/outputs/PG/sample_{i+1}.csv'
    try:
        thermal_PG = pd.read_csv(thermal_PG_path, header=None, index_col=None).to_numpy()
    except FileNotFoundError:
        print(f'The file sample_{i+1} is not found')
        continue

    all_PG[thermal_bidx, :nt] = thermal_PG

    y_PG.append(all_PG.copy())
# Out:
# The file sample_4 is not found
# The file sample_8 is not found
# The file sample_15 is not found
# The file sample_25 is not found
# The file sample_27 is not found
# The file sample_35 is not found
# The file sample_37 is not found
# The file sample_41 is not found
# The file sample_42 is not found
# The file sample_43 is not found
# The file sample_45 is not found
# The file sample_57 is not found
# The file sample_58 is not found
# The file sample_64 is not found
# The file sample_71 is not found
# The file sample_80 is not found
# The file sample_81 is not found
# The file sample_85 is not found
# The file sample_86 is not found
# The file sample_89 is not found
# The file sample_91 is not found
# The file sample_97 is not found
# The file sample_99 is not found
# The file sample_102 is not found
# The file sample_114 is not found
# The file sample_124 is not found
# The file sample_144 is not found
# The file sample_149 is not found
# The file sample_152 is not found
# The file sample_158 is not found
# The file sample_175 is not found
# The file sample_176 is not found
# The file sample_185 is not found
# The file sample_207 is not found
# The file sample_210 is not found
# The file sample_214 is not found
# The file sample_224 is not found
# The file sample_225 is not found
# The file sample_240 is not found
# The file sample_253 is not found
# The file sample_263 is not found
# The file sample_273 is not found
# The file sample_274 is not found
# The file sample_285 is not found
# The file sample_287 is not found
# The file sample_297 is not found
# The file sample_306 is not found
# The file sample_313 is not found
# The file sample_324 is not found
# The file sample_325 is not found
# The file sample_328 is not found
# The file sample_334 is not found
# The file sample_335 is not found
# The file sample_336 is not found
# The file sample_340 is not found
# The file sample_355 is not found
# The file sample_360 is not found
# The file sample_366 is not found
# The file sample_388 is not found
# The file sample_390 is not found
# The file sample_398 is not found
# The file sample_414 is not found
# The file sample_415 is not found
# The file sample_419 is not found
# The file sample_420 is not found
# The file sample_428 is not found
# The file sample_430 is not found
# The file sample_436 is not found
# The file sample_438 is not found
# The file sample_440 is not found
# The file sample_441 is not found
# The file sample_443 is not found
# The file sample_449 is not found
# The file sample_450 is not found
# The file sample_453 is not found
# The file sample_454 is not found
# The file sample_470 is not found
# The file sample_488 is not found
# The file sample_498 is not found
# The file sample_500 is not found
# The file sample_509 is not found
# The file sample_513 is not found
# The file sample_523 is not found
# The file sample_539 is not found
# The file sample_554 is not found
# The file sample_555 is not found
# The file sample_570 is not found
# The file sample_578 is not found
# The file sample_581 is not found
# The file sample_586 is not found
# The file sample_603 is not found
# The file sample_612 is not found
# The file sample_615 is not found
# The file sample_617 is not found
# The file sample_621 is not found
# The file sample_639 is not found
# The file sample_641 is not found
# The file sample_643 is not found
# The file sample_654 is not found
# The file sample_659 is not found
# The file sample_665 is not found
# The file sample_666 is not found
# The file sample_677 is not found
# The file sample_679 is not found
# The file sample_680 is not found
# The file sample_681 is not found
# The file sample_683 is not found
# The file sample_691 is not found
# The file sample_692 is not found
# The file sample_697 is not found
# The file sample_700 is not found
# The file sample_718 is not found
# The file sample_728 is not found
# The file sample_737 is not found
# The file sample_754 is not found
# The file sample_757 is not found
# The file sample_766 is not found
# The file sample_770 is not found
# The file sample_778 is not found
# The file sample_782 is not found
# The file sample_783 is not found
# The file sample_797 is not found
# The file sample_798 is not found
# The file sample_802 is not found
# The file sample_809 is not found
# The file sample_812 is not found
# The file sample_814 is not found
# The file sample_821 is not found
# The file sample_822 is not found
# The file sample_824 is not found
# The file sample_829 is not found
# The file sample_831 is not found
# The file sample_837 is not found
# The file sample_840 is not found
# The file sample_844 is not found
# The file sample_846 is not found
# The file sample_847 is not found
# The file sample_851 is not found
# The file sample_855 is not found
# The file sample_857 is not found
# The file sample_863 is not found
# The file sample_866 is not found
# The file sample_868 is not found
# The file sample_870 is not found
# The file sample_871 is not found
# The file sample_872 is not found
# The file sample_873 is not found
# The file sample_886 is not found
# The file sample_888 is not found
# The file sample_891 is not found
# The file sample_900 is not found
# The file sample_917 is not found
# The file sample_918 is not found
# The file sample_930 is not found
# The file sample_931 is not found
# The file sample_932 is not found
# The file sample_933 is not found
# The file sample_939 is not found
# The file sample_944 is not found
# The file sample_945 is not found
# The file sample_947 is not found
# The file sample_950 is not found
# The file sample_959 is not found
# The file sample_960 is not found
# The file sample_965 is not found
# The file sample_996 is not found
# The file sample_1003 is not found
# The file sample_1004 is not found
# The file sample_1013 is not found
# The file sample_1014 is not found
# The file sample_1018 is not found
# The file sample_1023 is not found
# The file sample_1029 is not found
# The file sample_1046 is not found
# The file sample_1047 is not found
# The file sample_1059 is not found
# The file sample_1070 is not found
# The file sample_1071 is not found
# The file sample_1072 is not found
# The file sample_1076 is not found
# The file sample_1102 is not found
# The file sample_1108 is not found
# The file sample_1112 is not found
# The file sample_1114 is not found
# The file sample_1115 is not found
# The file sample_1119 is not found
# The file sample_1128 is not found
# The file sample_1133 is not found
# The file sample_1136 is not found
# The file sample_1140 is not found
# The file sample_1154 is not found
# The file sample_1157 is not found
# The file sample_1163 is not found
# The file sample_1167 is not found
# The file sample_1170 is not found
# The file sample_1171 is not found
# The file sample_1192 is not found
# The file sample_1195 is not found
# The file sample_1198 is not found

# %% [markdown]
# ## Edge index and attributes

# %%
# Read branch info
file_path = '../../data/IEEE_Case118/branch_params/branch_params.csv'
branch = pd.read_csv(file_path, header=None, index_col=None).to_numpy()

# Read and assign PF_max
RATE_A = 5                  # Index of RATE_A
########################## These numbers are determined separately ##############################
file_path = f'../../data/IEEE_Case118/branch_params/PF_max_category1.csv'
PF_max_category1 = pd.read_csv(file_path, header=None, index_col=None).to_numpy().astype(bool).flatten()
file_path = f'../../data/IEEE_Case118/branch_params/PF_max_category2.csv'
PF_max_category2 = pd.read_csv(file_path, header=None, index_col=None).to_numpy().astype(bool).flatten()
file_path = f'../../data/IEEE_Case118/branch_params/PF_max_category3.csv'
PF_max_category3 = pd.read_csv(file_path, header=None, index_col=None).to_numpy().astype(bool).flatten()
PF_max1 = 200
PF_max2 = 300
PF_max3 = 500
branch[PF_max_category1, RATE_A] = PF_max1
branch[PF_max_category2, RATE_A] = PF_max2
branch[PF_max_category3, RATE_A] = PF_max3

# Get branch index and attr
edge_index = branch[:, :2] - 1
edge_attr = branch[:, 2:]

# Convert to standard format
edge_index = torch.tensor(edge_index.T, dtype=torch.long)
edge_attr = torch.from_numpy(edge_attr).float()

# %% [markdown]
# ## ANN dataset

# %%
# Empty list to store data
x_ANN = []

# Get dimension of thermal, wind and load
num_thermal_features = thermal_gen_features.shape[1]
num_wind_features = nt
num_load_features = nt
num_UC = nt

# Empty node feature matrix
node_features = np.zeros((buses.shape[0], 
                          num_thermal_features+
                          num_wind_features+
                          num_load_features+
                          num_UC))

# Assign thermal features
node_features[thermal_bidx, :num_thermal_features] = thermal_gen_features

num = 0
# Assign wind and load features
for i in range(max_num):
    # File path
    wind_path = f'../../data/IEEE_Case118/inputs/wind/sample_{i+1}.csv'
    load_path = f'../../data/IEEE_Case118/inputs/load/sample_{i+1}.csv'

    # Read wind and load
    try:
        wind = pd.read_csv(wind_path, header=None, index_col=None)
        load = pd.read_csv(load_path, header=None, index_col=None)
    except FileNotFoundError:
        print(f'The file sample_{i+1} is not found')
        continue

    # Add UC ground truth
    UC_path = f'./model_evaluation/ANN/UC_pred_all/pred_{num+1}.csv'
    UC = pd.read_csv(UC_path, header=None, index_col=None)
    num += 1

    # Assign node features
    temp1 = num_thermal_features + num_wind_features
    temp2 = temp1 + num_load_features
    temp3 = temp2 + num_UC
    node_features[wind_bidx, num_thermal_features:temp1] = wind
    node_features[load_bidx, temp1:temp2] = load
    node_features[thermal_bidx, temp2:temp3] = UC[thermal_bidx]

    x_ANN.append(node_features.copy())
# Out:
# The file sample_4 is not found
# The file sample_8 is not found
# The file sample_15 is not found
# The file sample_25 is not found
# The file sample_27 is not found
# The file sample_35 is not found
# The file sample_37 is not found
# The file sample_41 is not found
# The file sample_42 is not found
# The file sample_43 is not found
# The file sample_45 is not found
# The file sample_57 is not found
# The file sample_58 is not found
# The file sample_64 is not found
# The file sample_71 is not found
# The file sample_80 is not found
# The file sample_81 is not found
# The file sample_85 is not found
# The file sample_86 is not found
# The file sample_89 is not found
# The file sample_91 is not found
# The file sample_97 is not found
# The file sample_99 is not found
# The file sample_102 is not found
# The file sample_114 is not found
# The file sample_124 is not found
# The file sample_144 is not found
# The file sample_149 is not found
# The file sample_152 is not found
# The file sample_158 is not found
# The file sample_175 is not found
# The file sample_176 is not found
# The file sample_185 is not found
# The file sample_207 is not found
# The file sample_210 is not found
# The file sample_214 is not found
# The file sample_224 is not found
# The file sample_225 is not found
# The file sample_240 is not found
# The file sample_253 is not found
# The file sample_263 is not found
# The file sample_273 is not found
# The file sample_274 is not found
# The file sample_285 is not found
# The file sample_287 is not found
# The file sample_297 is not found
# The file sample_306 is not found
# The file sample_313 is not found
# The file sample_324 is not found
# The file sample_325 is not found
# The file sample_328 is not found
# The file sample_334 is not found
# The file sample_335 is not found
# The file sample_336 is not found
# The file sample_340 is not found
# The file sample_355 is not found
# The file sample_360 is not found
# The file sample_366 is not found
# The file sample_388 is not found
# The file sample_390 is not found
# The file sample_398 is not found
# The file sample_414 is not found
# The file sample_415 is not found
# The file sample_419 is not found
# The file sample_420 is not found
# The file sample_428 is not found
# The file sample_430 is not found
# The file sample_436 is not found
# The file sample_438 is not found
# The file sample_440 is not found
# The file sample_441 is not found
# The file sample_443 is not found
# The file sample_449 is not found
# The file sample_450 is not found
# The file sample_453 is not found
# The file sample_454 is not found
# The file sample_470 is not found
# The file sample_488 is not found
# The file sample_498 is not found
# The file sample_500 is not found
# The file sample_509 is not found
# The file sample_513 is not found
# The file sample_523 is not found
# The file sample_539 is not found
# The file sample_554 is not found
# The file sample_555 is not found
# The file sample_570 is not found
# The file sample_578 is not found
# The file sample_581 is not found
# The file sample_586 is not found
# The file sample_603 is not found
# The file sample_612 is not found
# The file sample_615 is not found
# The file sample_617 is not found
# The file sample_621 is not found
# The file sample_639 is not found
# The file sample_641 is not found
# The file sample_643 is not found
# The file sample_654 is not found
# The file sample_659 is not found
# The file sample_665 is not found
# The file sample_666 is not found
# The file sample_677 is not found
# The file sample_679 is not found
# The file sample_680 is not found
# The file sample_681 is not found
# The file sample_683 is not found
# The file sample_691 is not found
# The file sample_692 is not found
# The file sample_697 is not found
# The file sample_700 is not found
# The file sample_718 is not found
# The file sample_728 is not found
# The file sample_737 is not found
# The file sample_754 is not found
# The file sample_757 is not found
# The file sample_766 is not found
# The file sample_770 is not found
# The file sample_778 is not found
# The file sample_782 is not found
# The file sample_783 is not found
# The file sample_797 is not found
# The file sample_798 is not found
# The file sample_802 is not found
# The file sample_809 is not found
# The file sample_812 is not found
# The file sample_814 is not found
# The file sample_821 is not found
# The file sample_822 is not found
# The file sample_824 is not found
# The file sample_829 is not found
# The file sample_831 is not found
# The file sample_837 is not found
# The file sample_840 is not found
# The file sample_844 is not found
# The file sample_846 is not found
# The file sample_847 is not found
# The file sample_851 is not found
# The file sample_855 is not found
# The file sample_857 is not found
# The file sample_863 is not found
# The file sample_866 is not found
# The file sample_868 is not found
# The file sample_870 is not found
# The file sample_871 is not found
# The file sample_872 is not found
# The file sample_873 is not found
# The file sample_886 is not found
# The file sample_888 is not found
# The file sample_891 is not found
# The file sample_900 is not found
# The file sample_917 is not found
# The file sample_918 is not found
# The file sample_930 is not found
# The file sample_931 is not found
# The file sample_932 is not found
# The file sample_933 is not found
# The file sample_939 is not found
# The file sample_944 is not found
# The file sample_945 is not found
# The file sample_947 is not found
# The file sample_950 is not found
# The file sample_959 is not found
# The file sample_960 is not found
# The file sample_965 is not found
# The file sample_996 is not found
# The file sample_1003 is not found
# The file sample_1004 is not found
# The file sample_1013 is not found
# The file sample_1014 is not found
# The file sample_1018 is not found
# The file sample_1023 is not found
# The file sample_1029 is not found
# The file sample_1046 is not found
# The file sample_1047 is not found
# The file sample_1059 is not found
# The file sample_1070 is not found
# The file sample_1071 is not found
# The file sample_1072 is not found
# The file sample_1076 is not found
# The file sample_1102 is not found
# The file sample_1108 is not found
# The file sample_1112 is not found
# The file sample_1114 is not found
# The file sample_1115 is not found
# The file sample_1119 is not found
# The file sample_1128 is not found
# The file sample_1133 is not found
# The file sample_1136 is not found
# The file sample_1140 is not found
# The file sample_1154 is not found
# The file sample_1157 is not found
# The file sample_1163 is not found
# The file sample_1167 is not found
# The file sample_1170 is not found
# The file sample_1171 is not found
# The file sample_1192 is not found
# The file sample_1195 is not found
# The file sample_1198 is not found

# %%
# Check the status of old dataset
dir = f'../../train_val_test_dataset/IEEE_Case118/PG-ANN/processed'
if not os.path.exists(dir):
    print(f'There is no dataset found!')
else:
    shutil.rmtree(dir)
    print(f'The old dataset has been deleted!')

# Save new dataset
data_list = []
for i in range(len(x_ANN)):
    X = torch.from_numpy(x_ANN[i]).float()
    Y = torch.from_numpy(y_PG[i]).float()
    graph = Data(x=X, y=Y, edge_index=edge_index, edge_attr=edge_attr)
    data_list.append(graph)

from MyDataset import MyDataset
# Not that if there is already saved dataset, this cell won't work
# Save train, val and test data
root = '../../train_val_test_dataset/IEEE_Case118/PG-ANN'
MyDataset(root=root, data_list=data_list)
# Out:
# The old dataset has been deleted!
# Processing...
# Done!
# MyDataset(1000)

# %% [markdown]
# ## SAGE dataset

# %%
# Empty list to store data
x_SAGE = []

# Get dimension of thermal, wind and load
num_thermal_features = thermal_gen_features.shape[1]
num_wind_features = nt
num_load_features = nt
num_UC = nt

# Empty node feature matrix
node_features = np.zeros((buses.shape[0], 
                          num_thermal_features+
                          num_wind_features+
                          num_load_features+
                          num_UC))

# Assign thermal features
node_features[thermal_bidx, :num_thermal_features] = thermal_gen_features


num = 0
# Assign wind and load features
for i in range(max_num):
    # File path
    wind_path = f'../../data/IEEE_Case118/inputs/wind/sample_{i+1}.csv'
    load_path = f'../../data/IEEE_Case118/inputs/load/sample_{i+1}.csv'

    # Read wind and load
    try:
        wind = pd.read_csv(wind_path, header=None, index_col=None)
        load = pd.read_csv(load_path, header=None, index_col=None)
    except FileNotFoundError:
        print(f'The file sample_{i+1} is not found')
        continue

    # Add UC ground truth
    UC_path = f'./model_evaluation/SAGE/UC_pred_all/pred_{num+1}.csv'
    UC = pd.read_csv(UC_path, header=None, index_col=None)
    num += 1

    # Assign node features
    temp1 = num_thermal_features + num_wind_features
    temp2 = temp1 + num_load_features
    temp3 = temp2 + num_UC
    node_features[wind_bidx, num_thermal_features:temp1] = wind
    node_features[load_bidx, temp1:temp2] = load
    node_features[thermal_bidx, temp2:temp3] = UC[thermal_bidx]

    x_SAGE.append(node_features.copy())
# Out:
# The file sample_4 is not found
# The file sample_8 is not found
# The file sample_15 is not found
# The file sample_25 is not found
# The file sample_27 is not found
# The file sample_35 is not found
# The file sample_37 is not found
# The file sample_41 is not found
# The file sample_42 is not found
# The file sample_43 is not found
# The file sample_45 is not found
# The file sample_57 is not found
# The file sample_58 is not found
# The file sample_64 is not found
# The file sample_71 is not found
# The file sample_80 is not found
# The file sample_81 is not found
# The file sample_85 is not found
# The file sample_86 is not found
# The file sample_89 is not found
# The file sample_91 is not found
# The file sample_97 is not found
# The file sample_99 is not found
# The file sample_102 is not found
# The file sample_114 is not found
# The file sample_124 is not found
# The file sample_144 is not found
# The file sample_149 is not found
# The file sample_152 is not found
# The file sample_158 is not found
# The file sample_175 is not found
# The file sample_176 is not found
# The file sample_185 is not found
# The file sample_207 is not found
# The file sample_210 is not found
# The file sample_214 is not found
# The file sample_224 is not found
# The file sample_225 is not found
# The file sample_240 is not found
# The file sample_253 is not found
# The file sample_263 is not found
# The file sample_273 is not found
# The file sample_274 is not found
# The file sample_285 is not found
# The file sample_287 is not found
# The file sample_297 is not found
# The file sample_306 is not found
# The file sample_313 is not found
# The file sample_324 is not found
# The file sample_325 is not found
# The file sample_328 is not found
# The file sample_334 is not found
# The file sample_335 is not found
# The file sample_336 is not found
# The file sample_340 is not found
# The file sample_355 is not found
# The file sample_360 is not found
# The file sample_366 is not found
# The file sample_388 is not found
# The file sample_390 is not found
# The file sample_398 is not found
# The file sample_414 is not found
# The file sample_415 is not found
# The file sample_419 is not found
# The file sample_420 is not found
# The file sample_428 is not found
# The file sample_430 is not found
# The file sample_436 is not found
# The file sample_438 is not found
# The file sample_440 is not found
# The file sample_441 is not found
# The file sample_443 is not found
# The file sample_449 is not found
# The file sample_450 is not found
# The file sample_453 is not found
# The file sample_454 is not found
# The file sample_470 is not found
# The file sample_488 is not found
# The file sample_498 is not found
# The file sample_500 is not found
# The file sample_509 is not found
# The file sample_513 is not found
# The file sample_523 is not found
# The file sample_539 is not found
# The file sample_554 is not found
# The file sample_555 is not found
# The file sample_570 is not found
# The file sample_578 is not found
# The file sample_581 is not found
# The file sample_586 is not found
# The file sample_603 is not found
# The file sample_612 is not found
# The file sample_615 is not found
# The file sample_617 is not found
# The file sample_621 is not found
# The file sample_639 is not found
# The file sample_641 is not found
# The file sample_643 is not found
# The file sample_654 is not found
# The file sample_659 is not found
# The file sample_665 is not found
# The file sample_666 is not found
# The file sample_677 is not found
# The file sample_679 is not found
# The file sample_680 is not found
# The file sample_681 is not found
# The file sample_683 is not found
# The file sample_691 is not found
# The file sample_692 is not found
# The file sample_697 is not found
# The file sample_700 is not found
# The file sample_718 is not found
# The file sample_728 is not found
# The file sample_737 is not found
# The file sample_754 is not found
# The file sample_757 is not found
# The file sample_766 is not found
# The file sample_770 is not found
# The file sample_778 is not found
# The file sample_782 is not found
# The file sample_783 is not found
# The file sample_797 is not found
# The file sample_798 is not found
# The file sample_802 is not found
# The file sample_809 is not found
# The file sample_812 is not found
# The file sample_814 is not found
# The file sample_821 is not found
# The file sample_822 is not found
# The file sample_824 is not found
# The file sample_829 is not found
# The file sample_831 is not found
# The file sample_837 is not found
# The file sample_840 is not found
# The file sample_844 is not found
# The file sample_846 is not found
# The file sample_847 is not found
# The file sample_851 is not found
# The file sample_855 is not found
# The file sample_857 is not found
# The file sample_863 is not found
# The file sample_866 is not found
# The file sample_868 is not found
# The file sample_870 is not found
# The file sample_871 is not found
# The file sample_872 is not found
# The file sample_873 is not found
# The file sample_886 is not found
# The file sample_888 is not found
# The file sample_891 is not found
# The file sample_900 is not found
# The file sample_917 is not found
# The file sample_918 is not found
# The file sample_930 is not found
# The file sample_931 is not found
# The file sample_932 is not found
# The file sample_933 is not found
# The file sample_939 is not found
# The file sample_944 is not found
# The file sample_945 is not found
# The file sample_947 is not found
# The file sample_950 is not found
# The file sample_959 is not found
# The file sample_960 is not found
# The file sample_965 is not found
# The file sample_996 is not found
# The file sample_1003 is not found
# The file sample_1004 is not found
# The file sample_1013 is not found
# The file sample_1014 is not found
# The file sample_1018 is not found
# The file sample_1023 is not found
# The file sample_1029 is not found
# The file sample_1046 is not found
# The file sample_1047 is not found
# The file sample_1059 is not found
# The file sample_1070 is not found
# The file sample_1071 is not found
# The file sample_1072 is not found
# The file sample_1076 is not found
# The file sample_1102 is not found
# The file sample_1108 is not found
# The file sample_1112 is not found
# The file sample_1114 is not found
# The file sample_1115 is not found
# The file sample_1119 is not found
# The file sample_1128 is not found
# The file sample_1133 is not found
# The file sample_1136 is not found
# The file sample_1140 is not found
# The file sample_1154 is not found
# The file sample_1157 is not found
# The file sample_1163 is not found
# The file sample_1167 is not found
# The file sample_1170 is not found
# The file sample_1171 is not found
# The file sample_1192 is not found
# The file sample_1195 is not found
# The file sample_1198 is not found

# %%
# Check the status of old dataset
dir = f'../../train_val_test_dataset/IEEE_Case118/PG-SAGE/processed'
if not os.path.exists(dir):
    print(f'There is no dataset found!')
else:
    shutil.rmtree(dir)
    print(f'The old dataset has been deleted!')

# Save new dataset
data_list = []
for i in range(len(x_SAGE)):
    X = torch.from_numpy(x_SAGE[i]).float()
    Y = torch.from_numpy(y_PG[i]).float()
    graph = Data(x=X, y=Y, edge_index=edge_index, edge_attr=edge_attr)
    data_list.append(graph)

from MyDataset import MyDataset
# Not that if there is already saved dataset, this cell won't work
# Save train, val and test data
root = '../../train_val_test_dataset/IEEE_Case118/PG-SAGE'
MyDataset(root=root, data_list=data_list)
# Out:
# The old dataset has been deleted!
# Processing...
# Done!
# MyDataset(1000)

# %% [markdown]
# ## GCN dataset

# %%
# Empty list to store data
x_GCN = []

# Get dimension of thermal, wind and load
num_thermal_features = thermal_gen_features.shape[1]
num_wind_features = nt
num_load_features = nt
num_UC = nt

# Empty node feature matrix
node_features = np.zeros((buses.shape[0], 
                          num_thermal_features+
                          num_wind_features+
                          num_load_features+
                          num_UC))

# Assign thermal features
node_features[thermal_bidx, :num_thermal_features] = thermal_gen_features

num = 0
# Assign wind and load features
for i in range(max_num):
    # File path
    wind_path = f'../../data/IEEE_Case118/inputs/wind/sample_{i+1}.csv'
    load_path = f'../../data/IEEE_Case118/inputs/load/sample_{i+1}.csv'

    # Read wind and load
    try:
        wind = pd.read_csv(wind_path, header=None, index_col=None)
        load = pd.read_csv(load_path, header=None, index_col=None)
    except FileNotFoundError:
        print(f'The file sample_{i+1} is not found')
        continue

    # Add UC ground truth
    UC_path = f'./model_evaluation/GCN/UC_pred_all/pred_{num+1}.csv'
    UC = pd.read_csv(UC_path, header=None, index_col=None)
    num += 1

    # Assign node features
    temp1 = num_thermal_features + num_wind_features
    temp2 = temp1 + num_load_features
    temp3 = temp2 + num_UC
    node_features[wind_bidx, num_thermal_features:temp1] = wind
    node_features[load_bidx, temp1:temp2] = load
    node_features[thermal_bidx, temp2:temp3] = UC[thermal_bidx]

    x_GCN.append(node_features.copy())
# Out:
# The file sample_4 is not found
# The file sample_8 is not found
# The file sample_15 is not found
# The file sample_25 is not found
# The file sample_27 is not found
# The file sample_35 is not found
# The file sample_37 is not found
# The file sample_41 is not found
# The file sample_42 is not found
# The file sample_43 is not found
# The file sample_45 is not found
# The file sample_57 is not found
# The file sample_58 is not found
# The file sample_64 is not found
# The file sample_71 is not found
# The file sample_80 is not found
# The file sample_81 is not found
# The file sample_85 is not found
# The file sample_86 is not found
# The file sample_89 is not found
# The file sample_91 is not found
# The file sample_97 is not found
# The file sample_99 is not found
# The file sample_102 is not found
# The file sample_114 is not found
# The file sample_124 is not found
# The file sample_144 is not found
# The file sample_149 is not found
# The file sample_152 is not found
# The file sample_158 is not found
# The file sample_175 is not found
# The file sample_176 is not found
# The file sample_185 is not found
# The file sample_207 is not found
# The file sample_210 is not found
# The file sample_214 is not found
# The file sample_224 is not found
# The file sample_225 is not found
# The file sample_240 is not found
# The file sample_253 is not found
# The file sample_263 is not found
# The file sample_273 is not found
# The file sample_274 is not found
# The file sample_285 is not found
# The file sample_287 is not found
# The file sample_297 is not found
# The file sample_306 is not found
# The file sample_313 is not found
# The file sample_324 is not found
# The file sample_325 is not found
# The file sample_328 is not found
# The file sample_334 is not found
# The file sample_335 is not found
# The file sample_336 is not found
# The file sample_340 is not found
# The file sample_355 is not found
# The file sample_360 is not found
# The file sample_366 is not found
# The file sample_388 is not found
# The file sample_390 is not found
# The file sample_398 is not found
# The file sample_414 is not found
# The file sample_415 is not found
# The file sample_419 is not found
# The file sample_420 is not found
# The file sample_428 is not found
# The file sample_430 is not found
# The file sample_436 is not found
# The file sample_438 is not found
# The file sample_440 is not found
# The file sample_441 is not found
# The file sample_443 is not found
# The file sample_449 is not found
# The file sample_450 is not found
# The file sample_453 is not found
# The file sample_454 is not found
# The file sample_470 is not found
# The file sample_488 is not found
# The file sample_498 is not found
# The file sample_500 is not found
# The file sample_509 is not found
# The file sample_513 is not found
# The file sample_523 is not found
# The file sample_539 is not found
# The file sample_554 is not found
# The file sample_555 is not found
# The file sample_570 is not found
# The file sample_578 is not found
# The file sample_581 is not found
# The file sample_586 is not found
# The file sample_603 is not found
# The file sample_612 is not found
# The file sample_615 is not found
# The file sample_617 is not found
# The file sample_621 is not found
# The file sample_639 is not found
# The file sample_641 is not found
# The file sample_643 is not found
# The file sample_654 is not found
# The file sample_659 is not found
# The file sample_665 is not found
# The file sample_666 is not found
# The file sample_677 is not found
# The file sample_679 is not found
# The file sample_680 is not found
# The file sample_681 is not found
# The file sample_683 is not found
# The file sample_691 is not found
# The file sample_692 is not found
# The file sample_697 is not found
# The file sample_700 is not found
# The file sample_718 is not found
# The file sample_728 is not found
# The file sample_737 is not found
# The file sample_754 is not found
# The file sample_757 is not found
# The file sample_766 is not found
# The file sample_770 is not found
# The file sample_778 is not found
# The file sample_782 is not found
# The file sample_783 is not found
# The file sample_797 is not found
# The file sample_798 is not found
# The file sample_802 is not found
# The file sample_809 is not found
# The file sample_812 is not found
# The file sample_814 is not found
# The file sample_821 is not found
# The file sample_822 is not found
# The file sample_824 is not found
# The file sample_829 is not found
# The file sample_831 is not found
# The file sample_837 is not found
# The file sample_840 is not found
# The file sample_844 is not found
# The file sample_846 is not found
# The file sample_847 is not found
# The file sample_851 is not found
# The file sample_855 is not found
# The file sample_857 is not found
# The file sample_863 is not found
# The file sample_866 is not found
# The file sample_868 is not found
# The file sample_870 is not found
# The file sample_871 is not found
# The file sample_872 is not found
# The file sample_873 is not found
# The file sample_886 is not found
# The file sample_888 is not found
# The file sample_891 is not found
# The file sample_900 is not found
# The file sample_917 is not found
# The file sample_918 is not found
# The file sample_930 is not found
# The file sample_931 is not found
# The file sample_932 is not found
# The file sample_933 is not found
# The file sample_939 is not found
# The file sample_944 is not found
# The file sample_945 is not found
# The file sample_947 is not found
# The file sample_950 is not found
# The file sample_959 is not found
# The file sample_960 is not found
# The file sample_965 is not found
# The file sample_996 is not found
# The file sample_1003 is not found
# The file sample_1004 is not found
# The file sample_1013 is not found
# The file sample_1014 is not found
# The file sample_1018 is not found
# The file sample_1023 is not found
# The file sample_1029 is not found
# The file sample_1046 is not found
# The file sample_1047 is not found
# The file sample_1059 is not found
# The file sample_1070 is not found
# The file sample_1071 is not found
# The file sample_1072 is not found
# The file sample_1076 is not found
# The file sample_1102 is not found
# The file sample_1108 is not found
# The file sample_1112 is not found
# The file sample_1114 is not found
# The file sample_1115 is not found
# The file sample_1119 is not found
# The file sample_1128 is not found
# The file sample_1133 is not found
# The file sample_1136 is not found
# The file sample_1140 is not found
# The file sample_1154 is not found
# The file sample_1157 is not found
# The file sample_1163 is not found
# The file sample_1167 is not found
# The file sample_1170 is not found
# The file sample_1171 is not found
# The file sample_1192 is not found
# The file sample_1195 is not found
# The file sample_1198 is not found

# %%
# Check the status of old dataset
dir = f'../../train_val_test_dataset/IEEE_Case118/PG-GCN/processed'
if not os.path.exists(dir):
    print(f'There is no dataset found!')
else:
    shutil.rmtree(dir)
    print(f'The old dataset has been deleted!')

# Save new dataset
data_list = []
for i in range(len(x_GCN)):
    X = torch.from_numpy(x_GCN[i]).float()
    Y = torch.from_numpy(y_PG[i]).float()
    graph = Data(x=X, y=Y, edge_index=edge_index, edge_attr=edge_attr)
    data_list.append(graph)

from MyDataset import MyDataset
# Not that if there is already saved dataset, this cell won't work
# Save train, val and test data
root = '../../train_val_test_dataset/IEEE_Case118/PG-GCN'
MyDataset(root=root, data_list=data_list)
# Out:
# The old dataset has been deleted!
# Processing...
# Done!
# MyDataset(1000)
